# %%
import google.generativeai as genai
from PIL import Image

def get_text_from_image_gemini(image_path, api_key):
    """
    Extracts text from an image using the Gemini API.

    Args:
        image_path: Path to the image file.
        api_key: Your Gemini API key.

    Returns:
        The extracted text as a string, or None if there was an error.
    """

    # Configure the Gemini API
    genai.configure(api_key=api_key)
    # Load the Gemini Pro Vision model
    model = genai.GenerativeModel('gemini-2.5-flash')
    # Load the image using PIL
    img = Image.open(image_path)
    # Prepare the prompt
    prompt = "tell me a story"  # Customize this prompt as needed
    # Generate content using the Gemini Pro Vision model
    response = model.generate_content([prompt])
    # Check for errors
    if response.prompt_feedback and response.prompt_feedback.block_reason:
        print(f"Error: Prompt was blocked. Reason: {response.prompt_feedback.block_reason}")
        return None
    # Extract the text from the response
    extracted_text = response.text.strip()
    return extracted_text

# %%
# Example Usage (replace with your actual image path and API key)
image_path = "captcha-img.jpg"  # Replace with the path to your image
api_key = "AIzaSyD9iMkzVlxqiq7_YQoTFtvSipxiV2kMFk0"  # Replace with your actual API key

extracted_text = get_text_from_image_gemini(image_path, api_key)

if extracted_text:
    print("Extracted Text:", extracted_text)
else:
    print("Text extraction failed.")
# Out:
# Extracted Text: The old man, Silas, lived by the sea, in a cottage so close to the cliffs that the spray of the waves often kissed his windows. He was a quiet man, with eyes the colour of ancient sea glass, and a beard like spun foam. Most days, he sat on his porch, carving tiny wooden birds, each one unique, each one perfect.
#
# But Silas had a secret, one he’d kept hidden for sixty years.
#
# When he was a boy, no bigger than a seagull's shadow, he’d heard whispers of a place beyond the known world, a place where the sky met the ocean not in a hazy line, but in a swirling vortex of colour and sound. A place where dreams went to be born.
#
# One moonless night, driven by a yearning he couldn't name, young Silas untied his father’s smallest fishing boat, a mere speck against the vast darkness, and set sail. He steered by the feeling in his gut, by the pull of the currents, and by the faint, iridescent glow he thought he saw far out on the horizon.
#
# Hours turned into what felt like days. The stars above him were a million scattered diamonds, but ahead, the glow intensified. It pulsed, a living aurora of violet, gold, and deep sea-blue. The air grew thick with a scent he’d never known – like salt and ozone and blooming night-flowers.
#
# Then, there it was: the Maelstrom of Dreams.
#
# It wasn't a destructive whirlpool, but a towering, spiralling column of light and energy. Wisps of colour peeled away from its edges, drifting like luminous jellyfish. And from within, came a sound – not a roar, but a chorus of whispers, of half-formed melodies, of nascent laughter and unborn sighs.
#
# Silas, mesmerized, drifted closer. One small, brilliant wisp of light detached itself from the maelstrom, spiralled gently, and settled right into his open palm. It was warm, like holding a sunbeam, and it hummed with a quiet, vibrant energy. It looked like a tiny, perfect star.
